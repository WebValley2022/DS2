# %%
f = open("download_uri.txt", "r")
uris = [i.strip() for i in f.read().split(" ")]

# %%
for uri in uri:
    # !wget $uri
# Out:
# --2022-07-20 17:33:31--  https://ereporting.blob.core.windows.net/downloadservice/IT_10_25060_2013_timeseries.csv
# Resolving ereporting.blob.core.windows.net (ereporting.blob.core.windows.net)... 20.60.223.100
# Connecting to ereporting.blob.core.windows.net (ereporting.blob.core.windows.net)|20.60.223.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2688223 (2.6M) [application/octet-stream]
# Saving to: ‘IT_10_25060_2013_timeseries.csv’
#
# IT_10_25060_2013_ti 100%[===================>]   2.56M  1.04MB/s    in 2.5s
#
# 2022-07-20 17:33:34 (1.04 MB/s) - ‘IT_10_25060_2013_timeseries.csv’ saved [2688223/2688223]
#
# --2022-07-20 17:33:34--  https://ereporting.blob.core.windows.net/downloadservice/IT_10_25060_2014_timeseries.csv
# Resolving ereporting.blob.core.windows.net (ereporting.blob.core.windows.net)... 20.60.223.100
# Connecting to ereporting.blob.core.windows.net (ereporting.blob.core.windows.net)|20.60.223.100|:443... connected.
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from scipy.fft import fft, ifft
import numpy as np

# %%
tdata = pd.read_csv("IT_10_25060_2013_timeseries.csv")
tdata
# Out:
#      Countrycode     Namespace AirQualityNetwork AirQualityStation  \
# 0             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 1             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 2             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 3             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 4             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# ...          ...           ...               ...               ...
# 8755          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8756          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8757          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8758          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8759          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
#
#      AirQualityStationEoICode                            SamplingPoint  \
# 0                     IT1859A  SPO.IT1859A_10_NDIR_2007-11-17_00:00:00
# ...

# %%
avedata = tdata.groupby(np.arange(len(tdata))//20).mean()

# %%
tdata["Concentration"].to_numpy()
# Out:
# array([0.7, 0.7, 0.7, ..., 1.4, 1.1, 1.5])

# %%
figure(figsize=(20, 10))
plt.plot(fft(tdata["Concentration"]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [58], in <cell line: 2>()
#       1 figure(figsize=(20, 10))
# ----> 2 plt.plot(fft(tdata["Concentration"]))
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/scipy/fft/_backend.py:23, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      21 if fn is None:
#      22     return NotImplemented
# ---> 23 return fn(*args, **kwargs)
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/scipy/fft/_pocketfft/basic.py:17, in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      14 if plan is not None:
#      15     raise NotImplementedError('Passing a precomputed plan is not yet '
#      16                               'supported by scipy.fft functions')
# ---> 17 tmp = _asfarray(x)
#      18 overwrite_x = overwrite_x or _datacopied(tmp, x)
#      19 norm = _normalization(norm, forward)
#
# ...

# %%
tdata[tdata["Concentration"] ]
# Out:
#      Countrycode     Namespace AirQualityNetwork AirQualityStation  \
# 0             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 1             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 2             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 3             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 4             IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# ...          ...           ...               ...               ...
# 8755          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8756          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8757          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8758          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
# 8759          IT  IT.ISPRA.AQD        NET.IT090A       STA.IT1859A
#
#      AirQualityStationEoICode                            SamplingPoint  \
# 0                     IT1859A  SPO.IT1859A_10_NDIR_2007-11-17_00:00:00
# ...
