# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

# %%
frame = pd.read_csv('../exports/appa1.csv')
frame.Time = pd.to_datetime(frame.Time)
appa_columns = frame.columns.to_numpy()[1:]

# %%
fig = plt.figure(figsize=(25, 120))
fig.suptitle('Appa 1 Params')
outer = gridspec.GridSpec(len(appa_columns), 2, wspace=0.2, hspace=0.9)
for index, column in enumerate(appa_columns):
    ax = plt.Subplot(fig, outer[index])
    ax.scatter(frame.Time, frame[column], color='red', alpha=0.4, label=column)
    ax.set_ylabel(column)
    ax.set_xlabel('mean_test_score')
    ax.legend()
    fig.add_subplot(ax)
fig.show()
# Out:
# C:\Users\londe\AppData\Local\Temp\ipykernel_7044\2056354540.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
frame.loc[frame.LaFeO3_1_heatR > 170, 'LaFeO3_1_heatR'] = np.nan
frame = frame.dropna()
frame.to_csv('../exports/appa1.csv')

# %%
frame = pd.read_csv('../exports/appa2.csv')
frame.Time = pd.to_datetime(frame.Time)
appa_columns = frame.columns.to_numpy()[1:]
fig = plt.figure(figsize=(25, 120))
fig.suptitle('Hyper Parameters')
outer = gridspec.GridSpec(len(appa_columns), 2, wspace=0.2, hspace=0.9)
for index, column in enumerate(appa_columns):
    ax = plt.Subplot(fig, outer[index])
    ax.scatter(frame.Time, frame[column], color='red', alpha=0.4, label=column)
    ax.set_ylabel(column)
    ax.set_xlabel('mean_test_score')
    ax.legend()
    fig.add_subplot(ax)
fig.show()
# Out:
# C:\Users\londe\AppData\Local\Temp\ipykernel_7044\2095578136.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
